# %% [markdown]
# # WeatherPy
# ----
#
# ## Analysis
# ### Hemisphere City count comparison
# Every time I have run the random city generator, more cities show up in the northern hemisphere vs the southern one.  There are also more cities in the Eastern hemisphere than in the West.  I Googled to see which of the hemispheres had higher population counts, which might support, or not support, what I was seeing.  I figured that it would support it, but was still surprised at how hight the percentages were, with 90% of the global population living in the north, and about 82% in the east.
#
# ### Surprise, it's winter right now!
# The coldest cities are all pretty much in the Northern hemisphere, which makes sense because it is winter in the north.  Cities close to the equator, and in the southern hemisphere (in summer) are warmer.  The wind speeds seem extreme the closest to the poles.
#
# ### Never dry at the equater
# Cities around the equator seem to be more humid.  Since the area is mostly tropical (rain forests and stuff), this makes sense!

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Using a zip object to combine the two lists
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
city_count = len(cities)
print(city_count)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setup for the weather API call
base_url = 'http://api.openweathermap.org/data/2.5/weather?'

# units
units = 'imperial'

# lists for each column
city_list = []
cloudiness = []
country = []
dates = []
humidity = []
lat = []
lng = []
maxTemp = []
windSpeed = []

city_count = 0

# Loop through cities and make the call...
for city in cities:

    # Build query URL
    query_url = base_url + 'appid=' + api_key + '&q=' + city.replace(' ', '%20') +'&units=' + units
  
    city_data = requests.get(query_url).json()
  
    # try to append the dictionairy values to the individual lists
    try:
        city_list.append(city_data['name'])
        cloudiness.append(city_data['clouds']['all'])
        country.append(city_data['sys']['country'])
        unix_ts = int(city_data['dt'])
        dates.append(datetime.fromtimestamp(unix_ts)) 
        humidity.append(city_data['main']['humidity'])
        lat.append(city_data['coord']['lat'])
        lng.append(city_data['coord']['lon'])
        maxTemp.append(city_data['main']['temp_max'])
        windSpeed.append(city_data['wind']['speed'])
        city_count += 1
        print(f'Processing city # {city_count}')

    except:
        print(f'Cannot find city: {city}')
# Out:
# Cannot find city: taolanaro
# Processing city # 1
# Processing city # 2
# Processing city # 3
# Processing city # 4
# Processing city # 5
# Processing city # 6
# Processing city # 7
# Processing city # 8
# Processing city # 9
# Processing city # 10
# Processing city # 11
# Processing city # 12
# Processing city # 13
# Cannot find city: bengkulu
# Processing city # 14
# Processing city # 15
# Processing city # 16
# Processing city # 17
# Processing city # 18
# Cannot find city: illoqqortoormiut
# Processing city # 19
# Processing city # 20
# Processing city # 21
# Cannot find city: belushya guba
# Processing city # 22
# Processing city # 23
# Processing city # 24
# Processing city # 25
# Processing city # 26
# Processing city # 27
# Processing city # 28
# Processing city # 29
# Processing city # 30
# Processing city # 31
# Processing city # 32
# Processing city # 33
# Processing city # 34
# Processing city # 35
# Processing city # 36
# Processing city # 37
# Processing city # 38
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({
    'name': city_list,
    'cloudiness': cloudiness,
    'country': country,
    'date': dates,
    'humidity': humidity,
    'lat': lat,
    'lng': lng,
    'maxTemp': maxTemp,
    'windSpeed': windSpeed
})

city_df.to_csv('city_data.csv')

# %% [markdown]
# ## Checking out the new dataframe

# %%
city_df.head(20)
# Out:
#             name  cloudiness country                date  humidity    lat  \
# 0          Bluff           0      AU 2019-11-16 19:42:47        15 -23.58
# 1        Te Anau          99      NZ 2019-11-16 19:43:29        77 -45.41
# 2    Khislavichi         100      RU 2019-11-16 19:46:07        94  54.19
# 3        Mataura          11      NZ 2019-11-16 19:38:52        58 -46.19
# 4         Bethel          75      US 2019-11-16 19:40:53        78  60.79
# 5         Albany           1      US 2019-11-16 19:39:30        53  42.65
# 6        Ushuaia          75      AR 2019-11-16 19:42:40        81 -54.81
# 7       Khatanga          93      RU 2019-11-16 19:41:38        88  71.98
# 8   Punta Arenas          75      CL 2019-11-16 19:38:52        66 -53.16
# 9          Aboso           0      GH 2019-11-16 19:46:08        95   5.36
# 10        Sangar         100      RU 2019-11-16 19:42:10        98  63.92
# 11       Qaanaaq         100      GL 2019-11-16 19:42:56        95  77.48
# ...

# %% [markdown]
# ## Checking out the city data
# - how many are above equator, below?
#     It seems like every time I run it, there are more cities in the northern hemisphere.  A quick google search reveals that 6.57 billion people live in the northern hemisphere, which is about 90 % of the human population.  That supports the shape of the data showing more cities in the north.
# - east vs. west?
#     It also seems like there are more cities in the Eastern hemisphere, and a similar google search reveals that about 82% of the global population lives in that hemisphere.  The data looks good!

# %%
# pluch out cities above the equator, to see how many we have
northCities = city_df.loc[city_df['lat']>0]
# save the count for the print
northCity_count = len(northCities)

# do the same for the south
southCities = city_df.loc[city_df['lat']<0]
# grab count
southCity_count = len(southCities)

# do the same for the western hemisphere
westCities = city_df.loc[city_df['lng']<0]
westCity_count = len(westCities)

# east
eastCities = city_df.loc[city_df['lng']>0]
eastCity_count = len(eastCities)

# print results
print(f'There are {northCity_count} cities north of the equator, and there are {southCity_count} cities south of it.')
print(f'There are {eastCity_count} cities east of the Prime meridian, and there are {westCity_count} cities west of it.')
# Out:
# There are 375 cities north of the equator, and there are 167 cities south of it.
# There are 325 cities east of the Prime meridian, and there are 217 cities west of it.

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# variable for first date (to use in title)
current_date =  city_df['date'][0]

# pandas df.plot, scattering latitude and max temp
city_df.plot.scatter(
    x = 'lat', 
    y = 'maxTemp', 
    c = 'LightBlue',
    edgecolor = 'black', 
    grid = True, 
    # I've run this a few times and the northern hemisphere seems to always have more cities. i think this frames that nicely
    xlim = (-90, 90), 
    # capping the temp at 120
    ylim = (-50, 120),
    # i like the square look, hope that's not a bad habit
    figsize = (12, 12)
)

# adding axis labels and a title
plt.ylabel('Max Temperature (F)', fontsize=20)
plt.xlabel('Latitude', fontsize=20)
plt.title(f'City Latitude vs. Max Temperature on {current_date}', fontsize=22)
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature on 2019-11-16 19:42:47')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# df.plot scattering latitude and humidity
city_df.plot.scatter(
    x = 'lat', 
    y = 'humidity',
    c = 'LightBlue',
    edgecolor = 'black',
    grid = True, 
    # same scale to highlight the more NH cities
    xlim = (-90, 90),
    # just adding a little cushion, neg humidity and over 100% don't make sense
    ylim = (-10, 110),
    # square again
    figsize = (12, 12)    
)

# adding axis labels and a title
plt.ylabel('Humidity (%)', fontsize=20)
plt.xlabel('Latitude', fontsize=20)
plt.title(f'City Latitude vs. Humidity on {current_date}', fontsize=22)
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity on 2019-11-16 19:42:47')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# scatter chart, comparing latitiute and cloudiness
city_df.plot.scatter(
    x = 'lat', 
    y = 'cloudiness', 
    c = 'LightBlue',
    edgecolor = 'black',
    grid = True, 
    xlim = (-90, 90),
    # changing this slightly for cloudiness
    ylim = (-20, 120),
    figsize = (12, 12)    
)

# adding axis labels and a title
plt.ylabel('Cloudiness', fontsize=20)
plt.xlabel('Latitude', fontsize=20)
plt.title(f'City Latitude vs. Cloudiness on {current_date}', fontsize=22)
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness on 2019-11-16 19:42:47')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# scatter plot for lat and wind speed
city_df.plot.scatter(
    x = 'lat', 
    y = 'windSpeed', 
    c = 'LightBlue',
    edgecolor = 'black', 
    grid = True, 
    xlim = (-90, 90), 
    # limit wind speed to 40, go with 0 for base (thos really windy cities stand out)
    ylim = (0, 40),
    figsize = (12, 12)
)

# add axis labels and a title
plt.ylabel('Wind Speed', fontsize=20)
plt.xlabel('Latitude', fontsize=20)
plt.title(f'City Latitude vs. Wind Speed on {current_date}', fontsize=22)
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed on 2019-11-16 19:42:47')
